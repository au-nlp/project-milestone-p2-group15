# %%
## Incontect learning demo

# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from train_test_split import make_test_train_split

train, test = make_test_train_split() # split the category labelled problems into train (draw examples from) and test.
# Out:
# 130
# len(train_df)=65, len(test_df)=65

# %%
from in_context_learning_for_category_prediction import run_in_context_test
# run_in_context_test

# %% [raw]
# Predicted: Geometry | Actual: Geometry
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Number Theory | Actual: Algebra
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Geometry | Actual: Algebra
# Predicted: Geometry | Actual: Algebra
# Predicted: Geometry | Actual: Geometry
# Predicted: Number Theory | Actual: Number Theory
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Geometry | Actual: Algebra
# Predicted: Number Theory | Actual: Number Theory
# Predicted: Algebra | Actual: Algebra
# Predicted: Algebra | Actual: Algebra
# Predicted: Algebra | Actual: Algebra
# Predicted: Number Theory | Actual: Algebra
# Predicted: Algebra | Actual: Algebra
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Probability | Actual: Combinatorics
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
# Predicted: Algebra | Actual: Algebra
# Predicted: Geometry | Actual: Algebra
# Predicted: Algebra | Actual: Algebra
# Predicted: Probability | Actual: Combinatorics
# Predicted: Probability | Actual: Combinatorics
# Predicted: Probability | Actual: Combinatorics
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Probability | Actual: Combinatorics
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
# Predicted: Number Theory | Actual: Number Theory
# Predicted: Probability | Actual: Combinatorics
# Predicted: Number Theory | Actual: Algebra
# Predicted: Probability | Actual: Combinatorics
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Algebra | Actual: Algebra
# Predicted: Geometry | Actual: Geometry
# Predicted: Algebra | Actual: Algebra
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Number Theory | Actual: Number Theory
# Predicted: Number Theory | Actual: Number Theory
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Geometry | Actual: Geometry
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Probability | Actual: Geometry
# Predicted: Number Theory | Actual: Algebra
# Predicted: Geometry | Actual: Geometry
# Predicted: Algebra | Actual: Algebra
# Predicted: Probability | Actual: Combinatorics
# Predicted: Combinatorics | Actual: Combinatorics
# Predicted: Algebra | Actual: Algebra
# Predicted: Number Theory | Actual: Number Theory
# Predicted: Geometry | Actual: Geometry
# Predicted: Geometry | Actual: Geometry
#
# Accuracy: 73.85%

# %% [markdown]
# Running it yields the followint output
