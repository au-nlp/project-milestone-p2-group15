# %%
from multi_agent.multi_agent import Problem
from summerized_conv import summarized_conv


def P(Q: str, I: str, msg: str) -> str:
    return f"P(Q, I, {msg}"
z = summarized_conv(5, P=P, problem=Problem(roles=[], problem_descr="2+2", answer=4))
print(z)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 7
#       5 def P(Q: str, I: str, msg: str) -> str:
#       6     return f"P(Q, I, {msg}"
# ----> 7 z = summarized_conv(5, P=P, problem=Problem(roles=[], problem_descr="2+2", answer=4))
#       8 print(z)
#
# File c:\Users\Thomas\Documents\Datalogi\Kandidat\9. semester\9. semester notes\NLP\Project\NLP-group-15\multi_agent\multi_agent.py:28, in Problem.__init__(self, roles, problem_descr, answer)
#      27 def __init__(self, roles: list[Role], problem_descr: str, answer: str):
# ---> 28   self._set_all(roles, problem_descr, answer)
#
# File c:\Users\Thomas\Documents\Datalogi\Kandidat\9. semester\9. semester notes\NLP\Project\NLP-group-15\multi_agent\multi_agent.py:34, in Problem._set_all(self, roles, problem_descr, answer)
#      32 self.all_roles = roles
#      33 self.problem_description = problem_descr
# ...
